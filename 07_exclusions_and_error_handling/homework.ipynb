# %%
from datetime import datetime
from datetime import timedelta
from pprint import pprint

start_date = input('Введите дату в формате YYYY-MM-DD: ')
end_date = input('Введите дату в формате YYYY-MM-DD: ')
day_list = []
try:
    start_dt = datetime.strptime(start_date, '%Y-%m-%d')
    end_dt = datetime.strptime(end_date, '%Y-%m-%d')
    while start_dt < end_dt:
        day_list.append(start_dt.strftime('%Y-%m-%d'))
        start_dt += timedelta(days=+1)
except:
    pass
del day_list[0]
pprint(day_list)
# Out:
# Введите дату в формате YYYY-MM-DD: 2020-04-19
# Введите дату в формате YYYY-MM-DD: 2020-05-01
# ['2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30']

# %%
stream = ['2018-04-02', '2018-02-29', '2017-06-06', '2018-19-02', '2002-11-31', '2020-02-29']
for date in stream:
    try:
        valid_date = datetime.strptime(date, '%Y-%m-%d')
        print(True)
    except:
        print(False)
        pass
# Out:
# True
# False
# True
# False
# False
# True

# %%
DEFAULT_USER_COUNT = 3

# %%
def delete_and_return_last_user(region, default_list=['A100', 'A101', 'A102']):
    element_to_delete = default_list[-1]
    default_list.remove(element_to_delete)
    return default_list[DEFAULT_USER_COUNT - 2]

# %%
delete_and_return_last_user(1)
# Out:
# 'A101'

# %%
delete_and_return_last_user(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-bfb6c4f8c48e> in <module>
# ----> 1 delete_and_return_last_user(1)
#
# <ipython-input-2-f353876ed759> in delete_and_return_last_user(region, default_list)
#       2     element_to_delete = default_list[-1]
#       3     default_list.remove(element_to_delete)
# ----> 4     return default_list[DEFAULT_USER_COUNT - 2]
#
# IndexError: list index out of range

# %%
Насколько я понял, ошибка 'list index out of range' выводится при обращении 
к несуществующему индексу. Здесь после первого запуска список уменьшается на один элемент.
